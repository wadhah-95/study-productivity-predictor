# %%
import pandas as pd 
df=pd.read_csv("../data/study-sessions.csv")
df.head()
df.shape
df.columns
df.info()
df.describe()
df.groupby("productive")[["sleep_hours", "phone_usage_hours", "energy_level", "mood_level"]].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sleep_hours               20 non-null     float64
#  1   phone_usage_hours         20 non-null     float64
#  2   study_duration_planned    20 non-null     int64
#  3   study_start_hour          20 non-null     int64
#  4   subject_difficulty        20 non-null     int64
#  5   mood_level                20 non-null     int64
#  6   energy_level              20 non-null     int64
#  7   coffee_cups               20 non-null     int64
#  8   day_type                  20 non-null     object
#  9   previous_day_study_hours  20 non-null     float64
#  10  productive                20 non-null     object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 1.8+ KB
#        sleep_hours  phone_usage_hours  study_duration_planned  \
# ...
